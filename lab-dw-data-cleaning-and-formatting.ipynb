# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

# Load the dataset
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
df1 = pd.read_csv(url)

url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
df2 = pd.read_csv(url)

url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
df3 = pd.read_csv(url)

# %%
df1.head()

# %%
df2.head()

# %%
df3.head()

# %%
# Combine the cleaned datasets
merged_data = pd.concat([df1, df2, df3], ignore_index=True)

# %%
def clean_data(merged_data):
    # Convert column names to lowercase
    merged_data.columns = merged_data.columns.str.lower()

    # Replace white spaces in column names with underscores
    merged_data.columns = merged_data.columns.str.replace(' ', '_')

    # Standardize 'gender' column values
    merged_data['gender'] = merged_data['gender'].str.lower().replace({'male': 'M', 'female': 'F'})

    # Fill missing values in the 'gender' column with a specific value (e.g., 'F')
    merged_data['gender'].fillna('Unknown', inplace=True)

     # Standardize 'st' column values
    state_abbreviation = {"AZ": "Arizona", "Cali": "California", "WA": "Washington"}
    merged_data['state'] = df['st'].map(state_abbreviation).fillna(df['st'])

    # Remove '%' from 'customer_lifetime_value' and convert to float
    merged_data['customer_lifetime_value'] = merged_data['customer_lifetime_value'].str.replace('%', '').astype(float)
    
    # Replace specific education values
    education_replacement = {"Bachelors": "Bachelor"}
    merged_data['education'] = merged_data['education'].replace(education_replacement)
    
    # Standardize vehicle class values
    vehicle_class_replacement = {"Luxury SUV": "Luxury", "Sports Car": "Luxury"}
    merged_data['vehicle_class'] = merged_data['vehicle_class'].replace(vehicle_class_replacement)
    
    # Drop any rows with null values in key columns (optional)
    merged_data.dropna(subset=['customer', 'gender', 'education', 'income', 'vehicle_class'], inplace=True)

    return merged_data

# %%
merged_data_cleaned = clean_data(merged_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29988\1483805723.py in ?()
# ----> 1 merged_data_cleaned = clean_data(merged_data)
#
# ~\AppData\Local\Temp\ipykernel_29988\1712204781.py in ?(merged_data)
#       5     # Replace white spaces in column names with underscores
#       6     merged_data.columns = merged_data.columns.str.replace(' ', '_')
#       7
#       8     # Standardize 'gender' column values
# ----> 9     merged_data['gender'] = merged_data['gender'].str.lower().replace({'male': 'M', 'female': 'F'})
#      10
#      11     # Fill missing values in the 'gender' column with a specific value (e.g., 'F')
#      12     merged_data['gender'].fillna('Unknown', inplace=True)
#
# c:\Users\fjkha\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
import pandas as pd

# URL of the dataset
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"

# Load the dataset into a DataFrame
marketing_data = pd.read_csv(url)

# Display the first few rows of the dataset
print(marketing_data.head())

# Clean the data
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
marketing_data
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
# Create a pivot table summarizing total revenue for each sales channel
pivot_table = marketing_data.pivot_table(values='total_claim_amount', index='sales_channel', aggfunc='sum')

# Round the total revenue to 2 decimal points
pivot_table = pivot_table.round(2)

# Display the pivot table
print(pivot_table)
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.82
# Branch                 1301204.00
# Call Center             926600.82
# Web                     706600.04

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
# Create a pivot table showing the average customer lifetime value per gender and education level
pivot_table_clv = marketing_data.pivot_table(values='customer_lifetime_value', index='gender', columns='education', aggfunc='mean')

# Round the average values to 2 decimal points
pivot_table_clv = pivot_table_clv.round(2)

# Display the pivot table
print(pivot_table_clv)
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %%
pivot_table
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.82
# Branch                 1301204.00
# Call Center             926600.82
# Web                     706600.04

# %%
pivot_table_clv
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
